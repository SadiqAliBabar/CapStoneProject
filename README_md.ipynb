# %% [markdown]
# <a href="https://colab.research.google.com/github/SadiqAliBabar/CapStoneProject/blob/main/README_md.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Human Action Recognition (HAR) Project
# This project focuses on recognizing human actions in videos using a combination of Convolutional Neural Networks (CNN) and Long Short-Term Memory (LSTM) networks.
#
# ## Features
# - Video Processing: Converts input videos into frames for analysis.
# - Action Recognition: Predicts actions in the video frames using a trained model.
# - Output Generation: Saves the predicted results into a processed video.
#
# ## Project Structure
#
# HAR-Project/
#
# ├── models/
#
# ├── output_videos/
#
# ├── assets/
#
# ├── README.md
#
# ├── requirements.txt
#
# ├── notebook.ipynb

# %% [markdown]
# `Installation`
#
# Clone this repository:
#
# ```
# git clone <repository-link>
# cd HAR-Project
#
# ```
#
#
#
# ### Install the required dependencies:
#
# ```
# pip install -r requirements.txt
# ```
#
# Data is here : https://drive.google.com/drive/folders/1hqjOC6M3OmpwmAuBFAD99LR73ofpyXD5?usp=sharing
#
# ### Usage
# - `Run the Notebook`: Open the notebook.ipynb in a Jupyter environment.
# - `Input Video`: Place your video in the appropriate directory.
# - `Execute the Prediction`: Follow the steps in the notebook to generate predictions.
#
# - `Output`: The processed video with action predictions will be saved in the output_videos/ folder.

# %% [markdown]
# ## Showing Some magic of my project
# My project gain about the 81% accuracy :) not bad for a beginner.
#
# ![Screenshot 2024-12-24 182340.png](data:image/png;base64,...)

# %%
from IPython.display import HTML

# Google Drive file ID
file_id = "1SfbftbYXp-p4X4i8HXyBu_zlaIazSrCX"

# Embed HTML code for video preview with autoplay and loop enabled
video_embed_code = f"""
<iframe src="https://drive.google.com/file/d/{file_id}/preview?autoplay=1&loop=1&playlist={file_id}"
width="600" height="400" allow="autoplay">
</iframe>
"""

# Display the embedded video in the output cell
HTML(video_embed_code)
# Out:
# <iframe src="https://drive.google.com/file/d/1SfbftbYXp-p4X4i8HXyBu_zlaIazSrCX/preview?autoplay=1&loop=1&playlist=1SfbftbYXp-p4X4i8HXyBu_zlaIazSrCX"
# width="600" height="400" allow="autoplay">
# </iframe>

# %% [markdown]
# ## **Prediction**
#
# ## Video Demo
#
# <iframe src="https://drive.google.com/file/d/1SfbftbYXp-p4X4i8HXyBu_zlaIazSrCX/preview"
# width="600" height="400" allow="autoplay">
# </iframe>

# %%
# Google Drive file ID
file_id = "1JbqGvRbJeN-WvOooGSPLhMJmehjT2ZUE"

# Embed HTML code for video preview with autoplay and loop enabled
video_embed_code = f"""
<iframe src="https://drive.google.com/file/d/{file_id}/preview?autoplay=1&loop=1&playlist={file_id}"
width="600" height="400" allow="autoplay">
</iframe>
"""

# Display the embedded video in the output cell
HTML(video_embed_code)
# Out:
# <iframe src="https://drive.google.com/file/d/1JbqGvRbJeN-WvOooGSPLhMJmehjT2ZUE/preview?autoplay=1&loop=1&playlist=1JbqGvRbJeN-WvOooGSPLhMJmehjT2ZUE"
# width="600" height="400" allow="autoplay">
# </iframe>
